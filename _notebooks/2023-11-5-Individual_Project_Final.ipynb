# %% [markdown]
# ---
# comments: true
# layout: post
# title: Individual Final Project
# courses: {csp: {week: 11} }
# type: tangibles
# permalink: /teach/home
# ---

# %% [markdown]
# # Contributions to the final project

# %% [markdown]
# I was a backend developer.

# %% [markdown]
# ## Old code
#
# - A python class called "Player" which represents each soccer player
#
# - There is a weights list that correlates the probablility of packing a player to how high the overall of the player.
#
# ### Why it didn't work
#
# The code doesn't connect with the frontend because it was in the api

# %%
CF = "Center Forward"
ST = "Striker"
RB = "Right Back"
LB = "Left Back"
CM = "Central Midfield"
LW = "Left Wing"
CDM = "Central Defensive Midfield"
CB = "Center Back"
RM = "Right Midfield"
LM = "Left Midfield"
LD = "Left Back"
CAM = "Central Attacking Midfield"
RW = "Right Wing"
LWB = "Left Wing Back"
RWB = "Right Wing Back"

class Player:
    def __init__(self, name, pos, ovr, pac, sho, pas, dri, defe, phy):
        self.name = name
        self.pos = pos
        self.ovr = ovr
        self.pac = pac
        self.sho = sho
        self.pas = pas
        self.dri = dri
        self.defe = defe
        self.phy = phy

players = [
    (Player("Lionel Messi", CF, 90, 80, 87, 90, 94, 33, 64), 1 / 100),
    (Player("Cristiano Ronaldo", ST, 86, 85, 90, 75, 92, 45, 78), 1 / 86),
    (Player("Erling Haaland", ST, 91, 89, 93, 66, 80, 24, 88), 1 / 91),
    (Player("Kylian Mbappe", ST, 91, 97, 90, 80, 92, 36, 78), 1 / 91),
    (Player("Sergi Roberto", RB, 80, 74, 63, 79, 77, 75, 73), 1 / 40),
    (Player("Ryota Morioka", CM, 72, 42, 69, 74, 69, 71, 68), 1 / 40),
    (Player("Kevin De Bruyne", CM, 91, 72, 88, 94, 87, 65, 78), 1 / 91),
    (Player("Neymar Jr", LW, 89, 86, 83, 85, 93, 37, 61), 1 / 89),
    (Player("Sandro Tonali", CDM, 86, 84, 74, 81, 81, 82, 84), 1 / 70),
    (Player("Qiu Zhongyi", CB, 48, 56, 25, 27, 34, 51, 52), 1 / 35),
    (Player("Marcus Rashford", LW, 85, 90, 86, 78, 84, 42, 74), 1 / 85),
    (Player("Vinicius Jr", LW, 89, 95, 82, 78, 90, 29, 68), 1 / 89),
    (Player("Bruno Fernandes", CAM, 88, 71, 86, 90, 83, 69, 77), 1 / 88),
    (Player("Heung Min Son", LW, 87, 87, 88, 80, 84, 42, 70), 1 / 88),
    (Player("Kaoru Mitoma", LM, 80, 84, 73, 74, 85, 57, 65), 1 / 45),
    (Player("Eberechi Eze", CAM, 79, 77, 76, 77, 82, 49, 68), 1 / 50),
    (Player("Chris Donnell", CM, 55, 63, 47, 52, 56, 48, 65), 1 / 35),
    (Player("Son Seung Woo", RWB, 48, 62, 26, 34, 44, 47, 51), 1 / 40),
    (Player("Jayden Harris", CDM, 58, 66, 48, 53, 54, 54, 69), 1 / 70),
    (Player("James Madisson", CAM, 84, 71, 81, 86, 86, 54, 63), 1 / 67),
    (Player("James Gibbons", RB, 62, 71, 43, 57, 62, 58, 64), 1 / 35),
    (Player("Paulo Dybala", CF, 86, 80, 85, 85, 90, 40, 60), 1 / 82),
    (Player("Hakan Calhanoglu", CM, 85, 67, 80, 86, 85, 70, 66), 1 / 70),
    (Player("Iago Aspas", ST, 85, 81, 85, 79, 86, 35, 64), 1 / 70),
    (Player("Antony", RM, 70, 83, 58, 63, 73, 38, 51), 1 / 50),
    (Player("Vakoun Issouf Bayo", ST, 70, 76, 70, 54, 67, 25, 77), 1 / 40),
    (Player("Noah Katterbach", LB, 69, 71, 40, 57, 72, 66, 58), 1 / 42),
    (Player("Paul Lasne", CDM, 69, 43, 61, 70, 67, 66, 70), 1 / 42),
    (Player("Auli Oliveros", CAM, 69, 81, 66, 66, 71, 59, 63), 1 / 42),
]

weights = [1 if player.ovr <= 70 else 0.5 for player, _ in players]

@app.route('/get_random_player', methods=["GET"])
def get_random_player():
    random_player, _ = random.choices(players, weights=weights)[0]
    player_info = {
        "Name": random_player.name,
        "Position": random_player.pos,  
        "Overall": random_player.ovr,  
        "Pace": random_player.pac,  
        "Shooting": random_player.sho,  
        "Passing": random_player.pas, 
        "Dribbling": random_player.dri,  
        "Defense": random_player.defe,  
        "Physicality": random_player.phy
    }
    return jsonify(player_info)

if __name__ == '__main__':
    app.run(host='localhost', port=8281)

# %% [markdown]
# ## New code
# - Used the jokes.py because it the code automatically stored the data that connects with the frontend
#
# - I defined the dictionary that contains information about various soccer players, including their names, positions, and statistics.
#
# - The dictinoary has key-value pairs, where each key is the name of a soccer player, and the corresponding value is another dictionary containing two key-value pairs: the position of the player and his/her stats (pace, dribbling, passing, shooting).
#
# - The dictionary organizes and stores data of the football players.

# %%
joke_list = {

    "Lionel Messi": {
        "position" : CF,
        "stats": [90, 80, 87, 90, 94, 33, 64]
    },
    "Cristiano Ronaldo" : {
        "position" : ST,
        "stats": [86, 85, 90, 75, 92, 45, 78]
    },
    "Kylian Mbappe": {
        "position" : ST,
        "stats": {91, 97, 90, 80, 92, 36, 78}
    },

    "Sergi Roberto": {
        "position" : RB,
        "stats": {80, 74, 63, 79, 77, 75, 73}
    },

    "Ryota Morioka": {
        "Position" : CM,
        "stats": {72, 42, 69, 74, 69, 71, 68}
    },
    "Erling Haaland": {
        "position" : ST,
        "stats" : [91, 89, 93, 66, 80, 24, 88]
    },
    "Kevin DeBruyne": {
        "position": CM,
        "stats" : [91, 72, 88, 94, 87, 65, 78]
    },
    "Sandro Tonali": {
        "position": CM,
        "stats": [86, 84, 74, 81, 81, 82, 84]
    },
    "Qiu Zhongyi": {
        "position": CB,
        "stats": [48, 56, 25, 27, 34, 51, 52]
    },
    "Marcus Rashford": {
        "position": LW,
        "stats": [85, 90, 86, 78, 84, 42, 74]
    },
    "Vinicius Jr": {
        "position": LW,
        "stats": [89, 95, 82, 78, 90, 29, 68]
    },
    "Bruno Fernandes": {
        "position": CAM,
        "stats": [88, 71, 86, 90, 83, 69, 77]
    },
    "Kaoru Mitoma": {
        "position": LM,
        "stats": [80, 84, 73, 74, 85, 57, 65]
    },
    "Eberechi Eze": {
        "position": CAM,
        "stats": [79, 77, 76, 77, 82, 49, 68]
    },
    "Chris Donell": {
        "position": CM,
        "stats": [55, 63, 47, 52, 56, 48, 65]
    },
    "Son Seung Woo": {
        "position": RWB,
        "stats": [48, 62, 26, 34, 44, 47, 51]
    },
    "Jayden Harris": {
        "position": CDM,
        "stats": [58, 66, 48, 53, 54, 54, 69]    
    },
    "James Madisson": {
        "position": CAM,
        "stats": [84, 71, 81, 86, 86, 54, 63]
    },
    "Paulo Dybala": {
        "position": CF,
        "stats": [86, 80, 85, 85, 90, 40, 60]
    },
    "Hakan Calhanoglu": {
        "position": CM,
        "stats": [85, 67, 80, 86, 85, 70, 66]
    },
    "Iago Aspas": {
        "position": ST,
        "stats": [85, 81, 85, 79, 86, 35, 64]
    },
    "Antony": {
        "position": RM,
        "stats": [70, 83, 58, 63, 73, 38, 51]
    },
    "Noah Katterbach": {
        "position": LB,
        "stats": [69, 71, 40, 57, 72, 66, 58]
    }

# %% [markdown]
# ### Issues I faced
#
# - There was an error everytime I tried to commit changes.
#
# - When I try to press "resolve in merge editor", it didn't do anything
#
# ### How I countered/fixed it
#
# - During the time that it didn't work, I researched online and asked Mr. Mort for help.
#
# - I worked on the project alongside Patrick and Miguel's computers.
#
# - I decided to delete the repository and reinstall it.
#
# - The issue was that we were all commiting simultaneously.
#
# - It didn't happen again after we learned that commmiting changes at the same time was the problem.

# %% [markdown]
# # Team Test Reflection
# The team test was the first project we did as a team (Patrick, Miguel, Aidan).
#
# ### Challenges we faced
#
# Challenged us because we were only used to working as a pair.
# It was harder to divide the work.
#
# ## Down below is some of the work I did.

# %% [markdown]
# ## Program with a List
# A program that uses a list data structure to store a group of elements.

# %%
# Create a list of something
shopping_list = []
# Function to add something to the list
def add_to_list(item):
    shopping_list.append(item)
    print(f"Added '{item}' to the shopping list.")
# Function to remove something from the list
def remove_from_list(item):
    if item in shopping_list:
        shopping_list.remove(item)
        print(f"Removed '{item}' from the shopping list.")
# Example usage:
add_to_list("Apples")
add_to_list("Bananas")
remove_from_list("Apples")

# %% [markdown]
# ## Program with a Dictionary
# A dictionary allows you to store and retrieve key-value pairs.
# We stored the scores to the corresponding people

# %%
# Create a dictionary
student_scores = {
    "Alice": 95,
    "Bob": 89,
}
# Retrieve the values that are assigned
alice_score = student_scores["Alice"]
bob_score = student_scores["Bob"]
# Print the scores
print("Alice's score:", alice_score)
print("Bob's score:", bob_score)
#"student_scores" is a python dictionary that associates the students with their scores
# Alice and Bob are the keys and the scores they got are the values, therefore creating a key-value pair.

# %% [markdown]
# # Team Teach Reflection

# %% [markdown]
# The team teach was one of the most important projects that I did with my team
#
# - We split the work equally amongst each other
#
# - Research was done through collegeboard videos and chatgbt
#
# - Down below is some of the code I made and presented to the class

# %% [markdown]
# ### Same goal, different Process
#
# The examples show different processes to see if you got an A, passed, or failed on a test. However, these two algorithms yield different results. The first algorithm uses three different "if" statements which will check each condition independently so two messages can be displayed. The second algorithm uses an elif statement to ensure that only one of the three conditions will be displayed.

# %%
display("What did you get on your test?")
testScore = int(input())
if testScore > 90:
    display("You got an A!")
if testScore > 70:
    display("Congragulations. You didn't fail.")
if testScore < 70:
    display("You failed.")

# %%
display("What did you get on your test?")
testScore = int(input())
if testScore > 90:
    display("You got an A!")
elif testScore > 70:
    display("Congratulations. You didn't fail.")
else:
    display("You failed.")

# %% [markdown]
# # Team teaches for other teams
#
# ### Variables
#
# - This taught me how to create python variables which helped me in my FlaskPortfolio.
#
# Main Ideas:
#
# - requirements of variables
# - Data Types (Integer, Boolean, String)
# - Changing values
# - String and lists
#
# ### Algorithms
#
# - This taught me how to use pseudo code
#
# Main Ideas:
#
# - Sequencing
# - Selection
# - Iteration
# - Conditional statements
# - Loops
# - Strings
#
# ### Iterations
#
# - This taught me how to use true or false statements
#
# Main Ideas:
#
# - Iterations using words and lists
# - The repetition of a process or utterance
#
# ### Booleans
#
# - This taught me how to make a program repeat continuously until its goal
#
# Main Ideas:
#
# - Relational operators
# - Logical operators
#
# ### Lists and searches
#
# - This taught me how to organize data which was useful in my FlaskPortfolio
#
# -Main Ideas:
#
# - Defining the List
#
# ### Accessing Elements in a list
#
# - Storing Element at an Index to a variable
# - Setting an Element at an Index to a variable
# - Insert a value at a certain index
# - Adding another value to the list (append)
# - Removing a value from the List at a specific Index
# - Accessing the Length of a list
#
# ### Developing Procedures
#
# - This taught me how to organize my da ta more efficiently
#
# Main Ideas:
#
# - Name
# - Parameters
# - Algorithm
# - Return Values
# - Calling a Procedure
#
# ### Libraries
#
# - This taught me how to import different libraries, which consists of different codes that perform certain procedures.
#
# Main Ideas:
# - Modules
# - Standard Library
# - Third-party Libraries

# %% [markdown]
# # Practice Quiz from Collegeboard

# %% [markdown]
# ![Screenshot of Quiz](/images/images/ScreenShot2023-11-06at9.25.31PM.png)
#
# I got a 43/66 which is a 65%.
#
# ### Topics that I need improvement in
#
# One of my most missed topics on the quiz was 2.4 (Using Programs with Data).
#
# - I watched 2.4 Daily Video 1 and 2 where I learned how to process data and make an algorithm for analying data
#
# ### Topics I did well
#
# - One of my best topics was 2.3 (Extracting Information from Data) where I got a 7/7
#
# - Overall it was a good experience to get an idea of what the AP eaxm was like
#
# - It gave me confidence as I expected to get below a 50%

# %% [markdown]
# # Individual reflection

# %% [markdown]
# ### The benefits of having plans for student blogs
#
# Here is my blog: http://127.0.0.1:4200/studentactual/csp
#
# - Having a student blog allows you to efficiently organize all the work that you have done
#
# - Shows the effort you put into the class by seeing the date of every code you did
#
# - Weely plans allow me to have a goal on what I will accomplish by the end of the week
#
# - Although the weekly plan was almost never accurate, it was a very important part of helping me concentrate during class
#
# - Review tickets helped me by showing what I had accompolished in a week. It made me proud of what I did and gave me motivation to do the same for the following week
#
# - With review tickets, I could tell if the week was efficient or not and I can find out why

# %% [markdown]
# ### What I learned in tri 1
#
# - I learned how to use the terminal and the commands
#
# - I learned how to use github and how to use it to make a website
#
# - I learned about local hosts
#
# - I learned about agile methodology and what roles each group member has
#
# ### What I hope to learn in tri 2
#
# - I want to learn more about javascript
#
# - I hope to learn more about frontend of websites
#
# ### Biggest challenge
#
# - The biggest challenge was learning all the new material
# - Some of the homework hacks and popcorn hacks were very difficult, but with the help of my team, I was able to complete them
# - I think it was smart for the teachers to make the students teach the class themselves as it allows them to learn more and learn to work asa a team
#
#
# ### My work ethic
#
# - I give myself a 8/10 on my work ethic
#
# - There were some times that I was joking around with my friends while doing some work
#
#
# ### What I will change in tri 2
#
# - I haven't done that much code at home so I try to do at least 15 min of csp every day
#
# - I will communicate with my group and my brother who is a cs major more often to get help on things I am confused on
#
# - I will definitely be more efficent next trimester as I have a better understanding of the class
